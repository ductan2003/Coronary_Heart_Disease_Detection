# %%
# EXPERIMENT 1
import json
import matplotlib.pyplot as plt
import numpy as np
import matplotlib


matplotlib.rc('font', size=14)  # Set default font size for all elements
matplotlib.rc('axes', titlesize=18)  # Set title font size
matplotlib.rc('axes', labelsize=16)  # Set axes label font size
matplotlib.rc('xtick', labelsize=14)  # Set x-tick label font size
matplotlib.rc('ytick', labelsize=14)  # Set y-tick label font size
matplotlib.rc('legend', fontsize=14)  # Set legend font size

# Load the JSON data
with open('/Users/tannguyen/Coronary_Heart_Disease_Detection/PGCN/Thesis_log/DatasetA/24-12-06-23:35:33/log_until_54800.json') as f1, open('/Users/tannguyen/Coronary_Heart_Disease_Detection/PGCN/Thesis_log/DatasetB/24-12-06-23:39:34/log_until_57375.json') as f2:
    data1 = json.load(f1)
    data2 = json.load(f2)

# Prepare data for plotting
indexes1 = [entry['step'] for entry in data1]
num_nodes1 = [entry['num_nodes'] for entry in data1]
edges1 = [entry['num_edges'] for entry in data1]
mse_values1 = [entry["mse"] for entry in data1]
success_rate1 = [entry["success_rate"] for entry in data1]

indexes2 = [entry['step'] for entry in data2]
num_nodes2 = [entry['num_nodes'] for entry in data2]
edges2 = [entry['num_edges'] for entry in data2]
mse_values2 = [entry["mse"] for entry in data2]
success_rate2 = [entry["success_rate"] for entry in data2]

# Set line thickness
line_width = 2.0

# Plotting: Num nodes
plt.figure(figsize=(15, 5))
plt.plot(indexes1, num_nodes1, label="Dataset A (Bộ dữ liệu A)", color='blue', linewidth=line_width)
plt.plot(indexes2, num_nodes2, label="Dataset B (Bộ dữ liệu B)", color='orange', linewidth=line_width)
plt.xlabel("Step")
plt.ylabel("Number of nodes")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Plotting: MSE
plt.figure(figsize=(15, 5))
plt.plot(indexes1, mse_values1, label="Dataset A (Bộ dữ liệu A)", color='blue', linewidth=line_width)
plt.plot(indexes2, mse_values2, label="Dataset B (Bộ dữ liệu B)", color='orange', linewidth=line_width)
plt.xlabel("Step")
plt.ylabel("Mean Squared Error (MSE)")
plt.ylim(0, 0.5)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Plotting: Success rate
plt.figure(figsize=(15, 5))
plt.plot(indexes1, success_rate1, label="Dataset A (Bộ dữ liệu A)", color='blue', linewidth=line_width)
plt.plot(indexes2, success_rate2, label="Dataset B (Bộ dữ liệu B)", color='orange', linewidth=line_width)
plt.xlabel("Step")
plt.ylabel("Accuracy")
plt.ylim(0, 1)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Plotting: Edges
plt.figure(figsize=(15, 5))
plt.plot(indexes1, edges1, label="Dataset A (Bộ dữ liệu A)", color='blue', linewidth=line_width)
plt.plot(indexes2, edges2, label="Dataset B (Bộ dữ liệu B)", color='orange', linewidth=line_width)
plt.xlabel("Step")
plt.ylabel("Number of edges")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# EXPERIMENT 2
import json
import matplotlib.pyplot as plt
import numpy as np
import matplotlib


matplotlib.rc('font', size=14)  # Set default font size for all elements
matplotlib.rc('axes', titlesize=18)  # Set title font size
matplotlib.rc('axes', labelsize=16)  # Set axes label font size
matplotlib.rc('xtick', labelsize=14)  # Set x-tick label font size
matplotlib.rc('ytick', labelsize=14)  # Set y-tick label font size
matplotlib.rc('legend', fontsize=14)  # Set legend font size

# Load the JSON data
# B: NonOverlap
# A: Overlap

env1 = "/Users/tannguyen/Coronary_Heart_Disease_Detection/PGCN/Thesis_log/Env_Change/24-12-07-03:26:46/log_until_8750.json"
env2 = "/Users/tannguyen/Coronary_Heart_Disease_Detection/PGCN/Thesis_log/Env_Change/24-12-07-03:26:46/log_until_17200.json"
env3 = "/Users/tannguyen/Coronary_Heart_Disease_Detection/PGCN/Thesis_log/Env_Change/24-12-07-03:26:46/log_until_25180.json"
env4 = "/Users/tannguyen/Coronary_Heart_Disease_Detection/PGCN/Thesis_log/Env_Change/24-12-07-03:26:46/log_until_37360.json"
with open(env1) as f1, open(env2) as f2, open(env3) as f3, open(env4) as f4:
    data1 = json.load(f1)
    data2 = json.load(f2)
    data3 = json.load(f3)
    data4 = json.load(f4)

# Prepare data for plotting
indexes1 = [entry['step'] for entry in data1]
num_nodes1 = [entry['num_nodes'] for entry in data1]
edges1 = [entry['num_edges'] for entry in data1]
mse_values1 = [entry["mse"] for entry in data1]
success_rate1 = [entry["success_rate"] for entry in data1]

indexes2 = [entry['step'] for entry in data2]
num_nodes2 = [entry['num_nodes'] for entry in data2]
edges2 = [entry['num_edges'] for entry in data2]
mse_values2 = [entry["mse"] for entry in data2]
success_rate2 = [entry["success_rate"] for entry in data2]

indexes3 = [entry['step'] for entry in data3]
num_nodes3 = [entry['num_nodes'] for entry in data3]
edges3 = [entry['num_edges'] for entry in data3]
mse_values3 = [entry["mse"] for entry in data3]
success_rate3 = [entry["success_rate"] for entry in data3]

indexes4 = [entry['step'] for entry in data4]
num_nodes4 = [entry['num_nodes'] for entry in data4]
edges4 = [entry['num_edges'] for entry in data4]
mse_values4 = [entry["mse"] for entry in data4]
success_rate4 = [entry["success_rate"] for entry in data4]

# Set line thickness
line_width = 2.0

# Plotting: Num nodes
plt.figure(figsize=(15, 5))
plt.plot(indexes1, num_nodes1, label="Environment 1 (Môi trường 1)", color='orange', linewidth=line_width)
plt.plot(indexes2, num_nodes2, label="Environment 2 (Môi trường 2)", color='blue', linewidth=line_width)
plt.plot(indexes3, num_nodes3, label="Environment 3 (Môi trường 3)", color='#FF69B4', linewidth=line_width)
plt.plot(indexes4, num_nodes4, label="Environment 4 (Môi trường 4)", color='green', linewidth=line_width)
plt.xlabel("Step")
plt.ylabel("Number of nodes")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Plotting: MSE
plt.figure(figsize=(15, 5))
plt.plot(indexes1, mse_values1, label="Environment 1 (Môi trường 1)", color='orange', linewidth=line_width)
plt.plot(indexes2, mse_values2, label="Environment 2 (Môi trường 2)", color='blue', linewidth=line_width)
plt.plot(indexes3, mse_values3, label="Environment 3 (Môi trường 3)", color='#FF69B4', linewidth=line_width)
plt.plot(indexes4, mse_values4, label="Environment 4 (Môi trường 4)", color='green', linewidth=line_width)
plt.xlabel("Step")
plt.ylabel("Mean Squared Error (MSE)")
plt.ylim(0, 0.5)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Plotting: Success rate
plt.figure(figsize=(15, 5))
plt.plot(indexes1, success_rate1, label="Environment 1 (Môi trường 1)", color='orange', linewidth=line_width)
plt.plot(indexes2, success_rate2, label="Environment 2 (Môi trường 2)", color='blue', linewidth=line_width)
plt.plot(indexes3, success_rate3, label="Environment 3 (Môi trường 3)", color='#FF69B4', linewidth=line_width)
plt.plot(indexes4, success_rate4, label="Environment 4 (Môi trường 4)", color='green', linewidth=line_width)
plt.xlabel("Step")
plt.ylabel("Accuracy")
plt.ylim(0, 1)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Plotting: Edges
plt.figure(figsize=(15, 5))
plt.plot(indexes1, edges1, label="Environment 1 (Môi trường 1)", color='orange', linewidth=line_width)
plt.plot(indexes2, edges2, label="Environment 2 (Môi trường 2)", color='blue', linewidth=line_width)
plt.plot(indexes3, edges3, label="Environment 3 (Môi trường 3)", color='#FF69B4', linewidth=line_width)
plt.plot(indexes4, edges4, label="Environment 4 (Môi trường 4)", color='green', linewidth=line_width)
plt.xlabel("Step")
plt.ylabel("Number of edges")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import matplotlib


matplotlib.rc('font', size=14)  # Set default font size for all elements
matplotlib.rc('axes', titlesize=18)  # Set title font size
matplotlib.rc('axes', labelsize=16)  # Set axes label font size
matplotlib.rc('xtick', labelsize=14)  # Set x-tick label font size
matplotlib.rc('ytick', labelsize=14)  # Set y-tick label font size
matplotlib.rc('legend', fontsize=14)  # Set legend font size

def get_data(path):
    with open(path) as f1:
        data1 = json.load(f1)
    return data1

def get_detail(data1):
    indexes1 = [entry['step'] for entry in data1]
    num_nodes1 = [entry['num_nodes'] for entry in data1]
    edges1 = [entry['num_edges'] for entry in data1]
    return indexes1, num_nodes1, edges1

PGCN1 = get_data("/Users/tannguyen/Coronary_Heart_Disease_Detection/PGCN/Thesis_log/Env_Change/24-12-09-02:17:30/log_until_8750.json")
PGCN2 = get_data("/Users/tannguyen/Coronary_Heart_Disease_Detection/PGCN/Thesis_log/Env_Change/24-12-09-02:17:30/log_until_17200.json")
PGCN3 = get_data("/Users/tannguyen/Coronary_Heart_Disease_Detection/PGCN/Thesis_log/Env_Change/24-12-09-02:17:30/log_until_25180.json")
PGCN4 = get_data("/Users/tannguyen/Coronary_Heart_Disease_Detection/PGCN/Thesis_log/Env_Change/24-12-09-02:17:30/log_until_37360.json")

GNG1 = get_data("/Users/tannguyen/Coronary_Heart_Disease_Detection/MyGNG/theta20/8750.json")
GNG2 = get_data("/Users/tannguyen/Coronary_Heart_Disease_Detection/MyGNG/theta20/17200.json")
GNG3 = get_data("/Users/tannguyen/Coronary_Heart_Disease_Detection/MyGNG/theta20/25180.json")
GNG4 = get_data("/Users/tannguyen/Coronary_Heart_Disease_Detection/MyGNG/theta20/37360.json")

LLCS1 = get_data("/Users/tannguyen/Coronary_Heart_Disease_Detection/LLCS/Thesis_log/Env_Change/24-12-09-02:40:24/log_until_8750.json")
LLCS2 = get_data("/Users/tannguyen/Coronary_Heart_Disease_Detection/LLCS/Thesis_log/Env_Change/24-12-09-02:40:24/log_until_17200.json")
LLCS3 = get_data("/Users/tannguyen/Coronary_Heart_Disease_Detection/LLCS/Thesis_log/Env_Change/24-12-09-02:40:24/log_until_25180.json")
LLCS4 = get_data("/Users/tannguyen/Coronary_Heart_Disease_Detection/LLCS/Thesis_log/Env_Change/24-12-09-02:40:24/log_until_37360.json")

indexes1, num_nodes1, edges1 = get_detail(PGCN1)
indexes2, num_nodes2, edges2 = get_detail(PGCN2)
indexes3, num_nodes3, edges3 = get_detail(PGCN3)
indexes4, num_nodes4, edges4 = get_detail(PGCN4)

indexes5, num_nodes5, edges5 = get_detail(GNG1)
indexes6, num_nodes6, edges6 = get_detail(GNG2)
indexes7, num_nodes7, edges7 = get_detail(GNG3)
indexes8, num_nodes8, edges8 = get_detail(GNG4)

indexes9, num_nodes9, edges9 = get_detail(LLCS1)
indexes10, num_nodes10, edges10 = get_detail(LLCS2)
indexes11, num_nodes11, edges11 = get_detail(LLCS3)
indexes12, num_nodes12, edges12 = get_detail(LLCS4)


# Set line thickness
line_width = 2.0

# Define colors for each dataset
colors = {
    "PGCN": "blue",
    "GNG": "green",
    "LLCS": "orange"
}

# Plotting: Num nodes
plt.figure(figsize=(15, 5))

# Plot all environments for PGCN
plt.plot(indexes1, num_nodes1, color=colors["PGCN"], linewidth=line_width, label="_nolegend_")  # No legend for individual lines
plt.plot(indexes2, num_nodes2, color=colors["PGCN"], linewidth=line_width, label="_nolegend_")
plt.plot(indexes3, num_nodes3, color=colors["PGCN"], linewidth=line_width, label="_nolegend_")
plt.plot(indexes4, num_nodes4, color=colors["PGCN"], linewidth=line_width, label="PGCN-300")

# Plot all environments for GNG
plt.plot(indexes5, num_nodes5, color=colors["GNG"], linewidth=line_width, label="_nolegend_")
plt.plot(indexes6, num_nodes6, color=colors["GNG"], linewidth=line_width, label="_nolegend_")
plt.plot(indexes7, num_nodes7, color=colors["GNG"], linewidth=line_width, label="_nolegend_")
plt.plot(indexes8, num_nodes8, color=colors["GNG"], linewidth=line_width, label="GNG-20")

# Plot all environments for LLCS
plt.plot(indexes9, num_nodes9, color=colors["LLCS"], linewidth=line_width, label="_nolegend_")
plt.plot(indexes10, num_nodes10, color=colors["LLCS"], linewidth=line_width, label="_nolegend_")
plt.plot(indexes11, num_nodes11, color=colors["LLCS"], linewidth=line_width, label="_nolegend_")
plt.plot(indexes12, num_nodes12, color=colors["LLCS"], linewidth=line_width, label="LLCS")

# Customize the plot
plt.xlabel("Step")
plt.ylabel("Number of nodes")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Plotting: Edges
plt.figure(figsize=(15, 5))

# Plot all environments for PGCN
plt.plot(indexes1, edges1, color=colors["PGCN"], linewidth=line_width, label="_nolegend_")
plt.plot(indexes2, edges2, color=colors["PGCN"], linewidth=line_width, label="_nolegend_")
plt.plot(indexes3, edges3, color=colors["PGCN"], linewidth=line_width, label="_nolegend_")
plt.plot(indexes4, edges4, color=colors["PGCN"], linewidth=line_width, label="PGCN-300")

# Plot all environments for GNG
plt.plot(indexes5, edges5, color=colors["GNG"], linewidth=line_width, label="_nolegend_")
plt.plot(indexes6, edges6, color=colors["GNG"], linewidth=line_width, label="_nolegend_")
plt.plot(indexes7, edges7, color=colors["GNG"], linewidth=line_width, label="_nolegend_")
plt.plot(indexes8, edges8, color=colors["GNG"], linewidth=line_width, label="GNG-20")

# Plot all environments for LLCS
plt.plot(indexes9, edges9, color=colors["LLCS"], linewidth=line_width, label="_nolegend_")
plt.plot(indexes10, edges10, color=colors["LLCS"], linewidth=line_width, label="_nolegend_")
plt.plot(indexes11, edges11, color=colors["LLCS"], linewidth=line_width, label="_nolegend_")
plt.plot(indexes12, edges12, color=colors["LLCS"], linewidth=line_width, label="LLCS")

# Customize the plot
plt.xlabel("Step")
plt.ylabel("Number of edges")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
