# %%
import os
import glob
import matplotlib.pyplot as plt
import json
import pandas as pd

# %%
def load_and_save_logs(folder_path, output_folder):
    """
    This function loads all JSON files in the specified folder with the naming convention 'log_until_<step>.json',
    combines their data, and saves each of the four graphs (nodes, edges, MSE, and success rate) as separate images.
    """
    # Initialize an empty list to store data
    data = []
    
    # Load and combine data from all JSON files in the specified folder
    for file_path in glob.glob(os.path.join(folder_path, "log_until_*.json")):
        with open(file_path, 'r') as f:
            data.extend(json.load(f))
    
    # Convert to DataFrame
    df = pd.DataFrame(data)
    
    # Sort by step for correct plotting
    df = df.sort_values(by="step")

    # Ensure output folder exists
    os.makedirs(output_folder, exist_ok=True)

    # Plot each metric separately and save
    plt.figure(figsize=(10, 5))
    plt.plot(df["step"], df["num_nodes"], label="Number of Nodes")
    plt.xlabel("Step")
    plt.ylabel("Number of Nodes")
    plt.legend()
    plt.title("Number of Nodes Over Steps")
    plt.grid(True)
    plt.savefig(os.path.join(output_folder, "visualize_num_nodes.png"))
    # plt.show()
    plt.close()

    plt.figure(figsize=(10, 5))
    plt.plot(df["step"], df["num_edges"], label="Number of Edges", color="orange")
    plt.xlabel("Step")
    plt.ylabel("Number of Edges")
    plt.legend()
    plt.title("Number of Edges Over Steps")
    plt.grid(True)
    plt.savefig(os.path.join(output_folder, "visualize_num_edges.png"))
    # plt.show()
    plt.close()

    plt.figure(figsize=(10, 5))
    plt.plot(df["step"], df["mse"], label="MSE", color="green")
    plt.xlabel("Step")
    plt.ylabel("MSE")
    plt.legend()
    plt.title("MSE Over Steps")
    plt.grid(True)
    plt.savefig(os.path.join(output_folder, "visualize_mse.png"))
    # plt.show()
    plt.close()

    plt.figure(figsize=(10, 5))
    plt.plot(df["step"], df["success_rate"], label="Success Rate", color="red")
    plt.xlabel("Step")
    plt.ylabel("Success Rate")
    plt.legend()
    plt.title("Success Rate Over Steps")
    plt.grid(True)
    plt.savefig(os.path.join(output_folder, "visualize_success_rate.png"))
    # plt.show()
    plt.close()

# Usage example (commented out because the function requires a specific folder and output path):
# load_and_save_logs('/path/to/folder', '/path/to/output_folder')

# %%
log_path = '../Dataset_log/Experiment3/24-11-09-17:47:58/'
load_and_save_logs(log_path, log_path)

# %%
def load_and_save_logs_compare(folder_path1, folder_path2):
    """
    This function loads all JSON files in the specified folder with the naming convention 'log_until_<step>.json',
    combines their data, and saves each of the four graphs (nodes, edges, MSE, and success rate) as separate images.
    """
    # Initialize an empty list to store data
    data1 = []
    data2 = []
    # Load and combine data from all JSON files in the specified folder
    for file_path in glob.glob(os.path.join(folder_path1, "log_until_*.json")):
        with open(file_path, 'r') as f:
            data1.extend(json.load(f))
    for file_path in glob.glob(os.path.join(folder_path2, "log_until_*.json")):
        with open(file_path, 'r') as f:
            data2.extend(json.load(f))
    
    # Convert to DataFrame
    df1 = pd.DataFrame(data1)
    
    # Sort by step for correct plotting
    df1 = df1.sort_values(by="step")
    
    # Convert to DataFrame
    df2 = pd.DataFrame(data2)
    
    # Sort by step for correct plotting
    df2 = df2.sort_values(by="step")

    # # Ensure output folder exists
    # os.makedirs(output_folder, exist_ok=True)

    # Plot each metric separately and save
    plt.figure(figsize=(10, 5))
    plt.plot(df1["step"], df1["num_nodes"], label="Number of Nodes 1", color="orange")
    plt.plot(df2["step"], df2["num_nodes"], label="Number of Nodes 2", color="blue")
    plt.xlabel("Step")
    plt.ylabel("Number of Nodes")
    plt.legend()
    plt.title("Number of Nodes Over Steps")
    plt.grid(True)
    # plt.savefig(os.path.join(output_folder, "visualize_num_nodes.png"))
    plt.show()
    plt.close()

    plt.figure(figsize=(10, 5))
    plt.plot(df1["step"], df1["num_edges"], label="Number of Edges 1", color="orange")
    plt.plot(df2["step"], df2["num_edges"], label="Number of Edges 2", color="blue")
    plt.xlabel("Step")
    plt.ylabel("Number of Edges")
    plt.legend()
    plt.title("Number of Edges Over Steps")
    plt.grid(True)
    # plt.savefig(os.path.join(output_folder, "visualize_num_edges.png"))
    plt.show()
    plt.close()

    plt.figure(figsize=(10, 5))
    plt.plot(df1["step"], df1["mse"], label="MSE 1", color="orange")
    plt.plot(df2["step"], df2["mse"], label="MSE 2", color="blue")
    plt.xlabel("Step")
    plt.ylabel("MSE")
    plt.legend()
    plt.title("MSE Over Steps")
    plt.grid(True)
    # plt.savefig(os.path.join(output_folder, "visualize_mse.png"))
    plt.show()
    plt.close()

    plt.figure(figsize=(10, 5))
    plt.plot(df1["step"], df1["success_rate"], label="Success Rate 1", color="orange")
    plt.plot(df2["step"], df2["success_rate"], label="Success Rate 2", color="blue")
    plt.xlabel("Step")
    plt.ylabel("Success Rate")
    plt.legend()
    plt.title("Success Rate Over Steps")
    plt.grid(True)
    # plt.savefig(os.path.join(output_folder, "visualize_success_rate.png"))
    plt.show()
    plt.close()


# 3 epoch
# load_and_save_logs_compare('../Dataset_log/Experiment1_Overlap/24-11-07-20:49:05/', 
#                            '../Dataset_log/Experiment1_NonOverlap/24-11-07-20:49:36/')
# 2 epoch
# load_and_save_logs_compare('../Dataset_log/Experiment1_Overlap/24-11-07-20:38:16/', 
#                            '../Dataset_log/Experiment1_NonOverlap/24-11-07-20:39:03/')
# # 1 epoch
load_and_save_logs_compare('../Dataset_log/Experiment1_Overlap/24-11-07-20:27:31/', 
                           '../Dataset_log/Experiment1_NonOverlap/24-11-07-20:35:46/')

# %%
load_and_save_logs_compare('../Dataset_log/Experiment1_Overlap/24-11-09-14:31:35/', 
                           '../Dataset_log/Experiment1_NonOverlap/24-11-09-14:30:38/')
